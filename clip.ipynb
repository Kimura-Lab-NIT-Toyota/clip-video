# %%
import ffmpeg
import json
import cv2
import os

CONFIG_FILE = "./config.json"
config = {}
if(os.path.exists(CONFIG_FILE)):
    with open(CONFIG_FILE, "r") as f:
        config = json.load(f)
else: raise Exception(f"not found {CONFIG_FILE}")

# パスを全取得
with open(config["video_path_file"], "r") as f:
    paths = f.readlines()
# コアとなる時間を記したjsonを読み込む
with open(config["time_file"], "r") as f:
    coretimes = json.load(f)
# 未記入のパスがないかの確認
for path in paths:
    path = path.replace("\n", "").replace("\r", "")
    if(coretimes[path]["start"] == -1 or coretimes[path]["end"] == -1):
        print(path)

if(not os.path.exists(config["clipped_directory"])):
    os.mkdir(config["clipped_directory"])
for path in paths:
    # 改行文字を消去
    path = path.replace("\n", "").replace("\r", "")
    # 動画ファイルのフレームレートを取得
    cap = cv2.VideoCapture(path)
    print(cap.get(cv2.CAP_PROP_FPS))
    print(coretimes[path])
    # 保存先となるディレクトリ、なければ作成
    dir_path = f"{config['clipped_directory']}/{path.split('/')[-2]}"
    if (not os.path.isdir(dir_path)):
          os.mkdir(dir_path)
    # フレームレートと始終フレームから開始時間と動画長さを計算
    stream = ffmpeg.input(
        path,
        ss=coretimes[path]["start"]/cap.get(cv2.CAP_PROP_FPS),
        t =(coretimes[path]["end"] - coretimes[path]["start"]) / cap.get(cv2.CAP_PROP_FPS)
    ).output(f"{dir_path}/{path.split('/')[-1]}")
    # 保存
    ffmpeg.run(stream)
# Out:
# 29.666913860298664
# {'start': 28.0, 'end': 54.0}
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (13).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 477 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 399 kb/s, 29.67 fps, 29.67 tbr, 64528k tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 73 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x648aa9d38380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x648aa9d38380] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x648aa9d38380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (13).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 64528k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=   26 fps=0.0 q=-1.0 Lsize=      61kB time=00:00:00.80 bitrate= 620.6kbits/s speed=6.27x
# video:50kB audio:9kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.456667%
# [libx264 @ 0x648aa9d38380] frame I:1     Avg QP:18.98  size: 21742
# [libx264 @ 0x648aa9d38380] frame P:8     Avg QP:19.81  size:  2373
# [libx264 @ 0x648aa9d38380] frame B:17    Avg QP:20.33  size:   587
# [libx264 @ 0x648aa9d38380] consecutive B-frames:  7.7%  7.7% 23.1% 61.5%
# [libx264 @ 0x648aa9d38380] mb I  I16..4: 23.3% 56.1% 20.6%
# [libx264 @ 0x648aa9d38380] mb P  I16..4:  2.4%  3.1%  0.1%  P16..4: 22.3%  4.5%  2.1%  0.0%  0.0%    skip:65.5%
# [libx264 @ 0x648aa9d38380] mb B  I16..4:  0.2%  0.2%  0.0%  B16..8: 15.9%  0.6%  0.1%  direct: 1.8%  skip:81.3%  L0:43.4% L1:55.1% BI: 1.5%
# [libx264 @ 0x648aa9d38380] 8x8 transform intra:55.4% inter:76.0%
# [libx264 @ 0x648aa9d38380] coded y,uvDC,uvAC intra: 37.7% 45.8% 15.8% inter: 1.7% 5.5% 0.0%
# [libx264 @ 0x648aa9d38380] i16 v,h,dc,p: 32% 34% 17% 17%
# [libx264 @ 0x648aa9d38380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 20% 29%  1%  1%  2%  2%  1%  1%
# [libx264 @ 0x648aa9d38380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 21%  9%  3%  4%  5%  3%  5%  2%
# [libx264 @ 0x648aa9d38380] i8c dc,h,v,p: 56% 16% 26%  2%
# [libx264 @ 0x648aa9d38380] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x648aa9d38380] ref P L0: 71.1%  5.7% 16.0%  7.2%
# [libx264 @ 0x648aa9d38380] ref B L0: 82.2% 14.7%  3.1%
# [libx264 @ 0x648aa9d38380] ref B L1: 98.1%  1.9%
# [libx264 @ 0x648aa9d38380] kb/s:462.90
# [aac @ 0x648aa9d37480] Qavg: 134.766
# 29.66638310148632
# {'start': 34.0, 'end': 50.0}
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (18).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.33, start: 0.000000, bitrate: 439 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 362 kb/s, 29.67 fps, 29.67 tbr, 66224k tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 74 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x627cb8a02480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x627cb8a02480] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x627cb8a02480] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (18).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 66224k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=   16 fps=0.0 q=-1.0 Lsize=      38kB time=00:00:00.43 bitrate= 715.6kbits/s speed=4.64x
# video:32kB audio:5kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.880659%
# [libx264 @ 0x627cb8a02480] frame I:1     Avg QP:19.14  size: 17722
# [libx264 @ 0x627cb8a02480] frame P:4     Avg QP:20.43  size:  1962
# [libx264 @ 0x627cb8a02480] frame B:11    Avg QP:19.91  size:   553
# [libx264 @ 0x627cb8a02480] consecutive B-frames:  6.2%  0.0% 18.8% 75.0%
# [libx264 @ 0x627cb8a02480] mb I  I16..4: 26.0% 52.7% 21.3%
# [libx264 @ 0x627cb8a02480] mb P  I16..4:  2.2%  3.5%  0.1%  P16..4: 20.0%  3.7%  1.5%  0.0%  0.0%    skip:69.1%
# [libx264 @ 0x627cb8a02480] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 14.7%  0.6%  0.1%  direct: 1.7%  skip:82.7%  L0:50.7% L1:48.0% BI: 1.3%
# [libx264 @ 0x627cb8a02480] 8x8 transform intra:54.2% inter:79.8%
# [libx264 @ 0x627cb8a02480] coded y,uvDC,uvAC intra: 41.5% 47.9% 18.9% inter: 1.1% 4.8% 0.0%
# [libx264 @ 0x627cb8a02480] i16 v,h,dc,p: 31% 35% 15% 18%
# [libx264 @ 0x627cb8a02480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 49% 19% 24%  1%  1%  2%  1%  2%  1%
# [libx264 @ 0x627cb8a02480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 50% 24%  7%  3%  3%  4%  2%  5%  2%
# [libx264 @ 0x627cb8a02480] i8c dc,h,v,p: 52% 15% 30%  2%
# [libx264 @ 0x627cb8a02480] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x627cb8a02480] ref P L0: 76.2%  2.1% 15.9%  5.8%
# [libx264 @ 0x627cb8a02480] ref B L0: 84.9% 12.6%  2.5%
# [libx264 @ 0x627cb8a02480] ref B L1: 97.8%  2.2%
# [libx264 @ 0x627cb8a02480] kb/s:469.50
# [aac @ 0x627cb89dc980] Qavg: 4801.667
# 29.66678916726305
# {'start': 29.0, 'end': 57.0}
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (28).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.56, start: 0.000000, bitrate: 431 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 356 kb/s, 29.67 fps, 29.67 tbr, 10736500.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 73 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x59defbd23280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x59defbd23280] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x59defbd23280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (28).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 10736500.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=   28 fps=0.0 q=-1.0 Lsize=      55kB time=00:00:00.84 bitrate= 536.6kbits/s speed=6.88x
# video:46kB audio:8kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.774693%
# [libx264 @ 0x59defbd23280] frame I:1     Avg QP:17.24  size: 12963
# [libx264 @ 0x59defbd23280] frame P:7     Avg QP:17.95  size:  2406
# [libx264 @ 0x59defbd23280] frame B:20    Avg QP:19.88  size:   807
# [libx264 @ 0x59defbd23280] consecutive B-frames:  3.6%  0.0% 10.7% 85.7%
# [libx264 @ 0x59defbd23280] mb I  I16..4: 41.2% 45.2% 13.6%
# [libx264 @ 0x59defbd23280] mb P  I16..4:  5.1%  5.5%  0.1%  P16..4: 27.4%  4.0%  1.3%  0.0%  0.0%    skip:56.6%
# [libx264 @ 0x59defbd23280] mb B  I16..4:  0.3%  0.2%  0.0%  B16..8: 13.7%  0.4%  0.1%  direct: 8.2%  skip:77.2%  L0:45.2% L1:54.5% BI: 0.3%
# [libx264 @ 0x59defbd23280] 8x8 transform intra:47.4% inter:84.7%
# [libx264 @ 0x59defbd23280] coded y,uvDC,uvAC intra: 22.7% 57.3% 9.5% inter: 1.0% 14.4% 0.0%
# [libx264 @ 0x59defbd23280] i16 v,h,dc,p: 25% 44% 16% 14%
# [libx264 @ 0x59defbd23280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 26% 45%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x59defbd23280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 37% 10%  2%  3%  4%  2%  4%  2%
# [libx264 @ 0x59defbd23280] i8c dc,h,v,p: 47% 28% 23%  2%
# [libx264 @ 0x59defbd23280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x59defbd23280] ref P L0: 66.0%  1.9% 20.3% 11.9%
# [libx264 @ 0x59defbd23280] ref B L0: 85.2% 11.8%  3.0%
# [libx264 @ 0x59defbd23280] ref B L1: 96.4%  3.6%
# [libx264 @ 0x59defbd23280] kb/s:389.36
# [aac @ 0x59defbcfd640] Qavg: 135.917
# 29.667101857662225
# {'start': 32.0, 'end': 73.0}
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (41).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 400 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 321 kb/s, 29.67 fps, 29.67 tbr, 32290000.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 72 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x576cd6478980] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x576cd6478980] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x576cd6478980] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (41).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 32290000.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=   41 fps=0.0 q=-1.0 Lsize=      71kB time=00:00:01.28 bitrate= 451.4kbits/s speed=7.19x
# video:57kB audio:12kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.334477%
# [libx264 @ 0x576cd6478980] frame I:1     Avg QP:16.91  size: 14350
# [libx264 @ 0x576cd6478980] frame P:10    Avg QP:17.80  size:  2351
# [libx264 @ 0x576cd6478980] frame B:30    Avg QP:19.24  size:   651
# [libx264 @ 0x576cd6478980] consecutive B-frames:  2.4%  0.0%  0.0% 97.6%
# [libx264 @ 0x576cd6478980] mb I  I16..4: 39.8% 42.8% 17.3%
# [libx264 @ 0x576cd6478980] mb P  I16..4:  4.0%  5.2%  0.1%  P16..4: 24.3%  4.1%  1.2%  0.0%  0.0%    skip:61.1%
# [libx264 @ 0x576cd6478980] mb B  I16..4:  0.3%  0.2%  0.0%  B16..8: 13.1%  0.6%  0.0%  direct: 4.4%  skip:81.4%  L0:46.2% L1:53.1% BI: 0.8%
# [libx264 @ 0x576cd6478980] 8x8 transform intra:48.5% inter:81.3%
# [libx264 @ 0x576cd6478980] coded y,uvDC,uvAC intra: 23.1% 43.2% 7.8% inter: 1.1% 8.7% 0.0%
# [libx264 @ 0x576cd6478980] i16 v,h,dc,p: 27% 41% 19% 14%
# [libx264 @ 0x576cd6478980] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 25% 50%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x576cd6478980] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 42% 11%  2%  3%  3%  3%  3%  3%
# [libx264 @ 0x576cd6478980] i8c dc,h,v,p: 57% 21% 21%  1%
# [libx264 @ 0x576cd6478980] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x576cd6478980] ref P L0: 65.9%  2.2% 20.5% 11.4%
# [libx264 @ 0x576cd6478980] ref B L0: 85.1% 12.2%  2.8%
# [libx264 @ 0x576cd6478980] ref B L1: 96.3%  3.7%
# [libx264 @ 0x576cd6478980] kb/s:332.15
# [aac @ 0x576cd6451640] Qavg: 131.407
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (45).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.77, start: 0.000000, bitrate: 384 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 303 kb/s, 29.67 fps, 29.67 tbr, 66298000.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 73 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5983a8409980] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5983a8409980] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5983a8409980] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (45).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 66298000.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.40 bitrate=   1.0kbits/s speed=16.1x
# 29.666892941348618
# {'start': 31.0, 'end': 61.0}
# frame=   30 fps=0.0 q=-1.0 Lsize=      53kB time=00:00:01.00 bitrate= 429.1kbits/s speed=8.24x
# video:42kB audio:9kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.302576%
# [libx264 @ 0x5983a8409980] frame I:1     Avg QP:17.09  size: 13829
# [libx264 @ 0x5983a8409980] frame P:8     Avg QP:18.41  size:  1924
# [libx264 @ 0x5983a8409980] frame B:21    Avg QP:19.36  size:   600
# [libx264 @ 0x5983a8409980] consecutive B-frames:  6.7%  0.0%  0.0% 93.3%
# [libx264 @ 0x5983a8409980] mb I  I16..4: 37.7% 43.7% 18.6%
# [libx264 @ 0x5983a8409980] mb P  I16..4:  2.9%  4.4%  0.1%  P16..4: 19.5%  3.4%  1.3%  0.0%  0.0%    skip:68.4%
# [libx264 @ 0x5983a8409980] mb B  I16..4:  0.2%  0.2%  0.0%  B16..8: 12.7%  0.4%  0.0%  direct: 3.9%  skip:82.5%  L0:48.7% L1:50.7% BI: 0.6%
# [libx264 @ 0x5983a8409980] 8x8 transform intra:49.3% inter:81.4%
# [libx264 @ 0x5983a8409980] coded y,uvDC,uvAC intra: 25.9% 40.7% 8.2% inter: 1.0% 7.6% 0.0%
# [libx264 @ 0x5983a8409980] i16 v,h,dc,p: 28% 45% 14% 13%
# [libx264 @ 0x5983a8409980] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 27% 42%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x5983a8409980] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 44%  9%  2%  3%  3%  4%  3%  3%
# [libx264 @ 0x5983a8409980] i8c dc,h,v,p: 56% 23% 19%  1%
# [libx264 @ 0x5983a8409980] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5983a8409980] ref P L0: 69.5%  2.5% 18.4%  9.6%
# [libx264 @ 0x5983a8409980] ref B L0: 86.6% 11.9%  1.6%
# [libx264 @ 0x5983a8409980] ref B L1: 96.1%  3.9%
# [libx264 @ 0x5983a8409980] kb/s:330.85
# [aac @ 0x5983a8403480] Qavg: 2859.038
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (46).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.87, start: 0.000000, bitrate: 382 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 304 kb/s, 29.67 fps, 29.67 tbr, 66298000.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 73 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x60819ba9c5c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x60819ba9c5c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x60819ba9c5c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (46).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 66298000.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.22 bitrate=   1.7kbits/s speed=9.13x
# 29.666892941348618
# {'start': 31.0, 'end': 64.0}
# frame=   33 fps=0.0 q=-1.0 Lsize=      58kB time=00:00:01.03 bitrate= 458.0kbits/s speed=6.83x
# video:45kB audio:10kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.756693%
# [libx264 @ 0x60819ba9c5c0] frame I:1     Avg QP:16.69  size: 14469
# [libx264 @ 0x60819ba9c5c0] frame P:9     Avg QP:17.96  size:  1894
# [libx264 @ 0x60819ba9c5c0] frame B:23    Avg QP:19.41  size:   613
# [libx264 @ 0x60819ba9c5c0] consecutive B-frames:  3.0% 12.1%  0.0% 84.8%
# [libx264 @ 0x60819ba9c5c0] mb I  I16..4: 40.3% 42.3% 17.4%
# [libx264 @ 0x60819ba9c5c0] mb P  I16..4:  2.5%  4.0%  0.1%  P16..4: 19.8%  3.5%  1.3%  0.0%  0.0%    skip:68.7%
# [libx264 @ 0x60819ba9c5c0] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8: 11.8%  0.5%  0.1%  direct: 4.1%  skip:83.2%  L0:48.4% L1:50.8% BI: 0.8%
# [libx264 @ 0x60819ba9c5c0] 8x8 transform intra:48.4% inter:80.6%
# [libx264 @ 0x60819ba9c5c0] coded y,uvDC,uvAC intra: 26.5% 42.1% 8.5% inter: 1.0% 7.5% 0.0%
# [libx264 @ 0x60819ba9c5c0] i16 v,h,dc,p: 28% 42% 16% 13%
# [libx264 @ 0x60819ba9c5c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 27% 42%  1%  1%  1%  1%  1%  2%
# [libx264 @ 0x60819ba9c5c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 43% 11%  3%  3%  4%  3%  3%  3%
# [libx264 @ 0x60819ba9c5c0] i8c dc,h,v,p: 57% 23% 19%  2%
# [libx264 @ 0x60819ba9c5c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x60819ba9c5c0] ref P L0: 67.0%  2.0% 19.4% 11.6%
# [libx264 @ 0x60819ba9c5c0] ref B L0: 81.8% 15.0%  3.3%
# [libx264 @ 0x60819ba9c5c0] ref B L1: 96.8%  3.2%
# [libx264 @ 0x60819ba9c5c0] kb/s:328.08
# [aac @ 0x60819babea40] Qavg: 134.811
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (59).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
# ...
# [libx264 @ 0x5ea205519f80] mb P  I16..4:  2.2%  2.0%  0.1%  P16..4: 23.0%  3.3%  1.5%  0.0%  0.0%    skip:68.0%
# [libx264 @ 0x5ea205519f80] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 12.7%  0.5%  0.0%  direct: 1.9%  skip:84.7%  L0:41.3% L1:58.1% BI: 0.6%
# [libx264 @ 0x5ea205519f80] 8x8 transform intra:52.1% inter:84.9%
# [libx264 @ 0x5ea205519f80] coded y,uvDC,uvAC intra: 44.0% 57.0% 18.0% inter: 0.9% 6.2% 0.0%
# [libx264 @ 0x5ea205519f80] i16 v,h,dc,p: 26% 37% 12% 24%
# [libx264 @ 0x5ea205519f80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 26% 21%  2%  3%  3%  3%  3%  2%
# [libx264 @ 0x5ea205519f80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 24% 10%  3%  5%  5%  3%  5%  2%
# [libx264 @ 0x5ea205519f80] i8c dc,h,v,p: 52% 20% 26%  2%
# [libx264 @ 0x5ea205519f80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5ea205519f80] ref P L0: 73.4%  2.3% 15.5%  8.9%
# [libx264 @ 0x5ea205519f80] ref B L0: 82.9% 14.4%  2.8%
# [libx264 @ 0x5ea205519f80] ref B L1: 96.5%  3.5%
# [libx264 @ 0x5ea205519f80] kb/s:416.39
# [aac @ 0x5ea2054f69c0] Qavg: 126.343
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (104).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.39, start: 0.000000, bitrate: 391 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 310 kb/s, 29.67 fps, 29.67 tbr, 65910000.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 73 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56684e255a80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56684e255a80] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x56684e255a80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (104).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 65910000.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.26 bitrate=   1.5kbits/s speed=9.85x
# 29.66632473800598
# {'start': 31.0, 'end': 56.0}
# frame=   25 fps=0.0 q=-1.0 Lsize=      49kB time=00:00:00.74 bitrate= 540.0kbits/s speed=6.43x
# video:40kB audio:7kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.083924%
# [libx264 @ 0x56684e255a80] frame I:1     Avg QP:18.05  size: 19026
# [libx264 @ 0x56684e255a80] frame P:6     Avg QP:19.23  size:  2086
# [libx264 @ 0x56684e255a80] frame B:18    Avg QP:20.76  size:   492
# [libx264 @ 0x56684e255a80] consecutive B-frames:  4.0%  0.0%  0.0% 96.0%
# [libx264 @ 0x56684e255a80] mb I  I16..4: 28.5% 47.6% 23.8%
# [libx264 @ 0x56684e255a80] mb P  I16..4:  1.7%  1.9%  0.0%  P16..4: 20.9%  4.4%  1.9%  0.0%  0.0%    skip:69.0%
# [libx264 @ 0x56684e255a80] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 12.9%  0.5%  0.0%  direct: 1.9%  skip:84.5%  L0:50.5% L1:48.7% BI: 0.8%
# [libx264 @ 0x56684e255a80] 8x8 transform intra:47.9% inter:82.2%
# [libx264 @ 0x56684e255a80] coded y,uvDC,uvAC intra: 43.1% 53.6% 16.2% inter: 1.1% 6.0% 0.0%
# [libx264 @ 0x56684e255a80] i16 v,h,dc,p: 30% 34% 18% 18%
# [libx264 @ 0x56684e255a80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 27% 22%  2%  2%  2%  3%  3%  3%
# [libx264 @ 0x56684e255a80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 23%  9%  3%  7%  4%  4%  5%  2%
# [libx264 @ 0x56684e255a80] i8c dc,h,v,p: 51% 21% 26%  3%
# [libx264 @ 0x56684e255a80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56684e255a80] ref P L0: 72.7%  4.2% 15.3%  7.8%
# [libx264 @ 0x56684e255a80] ref B L0: 86.3% 11.2%  2.5%
# [libx264 @ 0x56684e255a80] ref B L1: 94.8%  5.2%
# [libx264 @ 0x56684e255a80] kb/s:383.55
# [aac @ 0x56684e2737c0] Qavg: 132.823
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/run/user/1000/gvfs/smb-share:server=kimlab-movie.local,share=disk1/学習データセット/手話単語・手話文データセット/手話単語/5級/video/500130-痛い/痛い (106).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.61.100
#   Duration: 00:00:02.60, start: 0.000000, bitrate: 370 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 800x600, 291 kb/s, 29.67 fps, 29.67 tbr, 16428500.00 tbn, 59.33 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 72 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x630536c8c3c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x630536c8c3c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x630536c8c3c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './clipped_videos/500130-痛い/痛い (106).mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 800x600, q=2-31, 29.67 fps, 16428500.00 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 22050 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.38 bitrate=   1.0kbits/s speed=14.4x
# 29.666166467128583
# {'start': 33.0, 'end': 60.0}
# frame=   27 fps=0.0 q=-1.0 Lsize=      51kB time=00:00:00.80 bitrate= 517.5kbits/s speed=6.56x
# video:42kB audio:7kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.023537%
# [libx264 @ 0x630536c8c3c0] frame I:1     Avg QP:17.83  size: 18615
# [libx264 @ 0x630536c8c3c0] frame P:7     Avg QP:19.17  size:  1852
# [libx264 @ 0x630536c8c3c0] frame B:19    Avg QP:20.81  size:   555
# [libx264 @ 0x630536c8c3c0] consecutive B-frames:  3.7%  7.4%  0.0% 88.9%
# [libx264 @ 0x630536c8c3c0] mb I  I16..4: 28.3% 48.3% 23.4%
# [libx264 @ 0x630536c8c3c0] mb P  I16..4:  2.0%  1.7%  0.1%  P16..4: 21.8%  3.6%  1.0%  0.0%  0.0%    skip:69.7%
# [libx264 @ 0x630536c8c3c0] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 13.5%  0.7%  0.0%  direct: 2.1%  skip:83.5%  L0:44.2% L1:54.6% BI: 1.2%
# [libx264 @ 0x630536c8c3c0] 8x8 transform intra:47.6% inter:85.0%
# [libx264 @ 0x630536c8c3c0] coded y,uvDC,uvAC intra: 40.7% 56.0% 18.4% inter: 1.0% 6.4% 0.0%
# [libx264 @ 0x630536c8c3c0] i16 v,h,dc,p: 31% 33% 17% 19%
# [libx264 @ 0x630536c8c3c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 22% 25%  2%  2%  3%  2%  3%  2%
# [libx264 @ 0x630536c8c3c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 25%  9%  2%  7%  4%  3%  4%  2%
# [libx264 @ 0x630536c8c3c0] i8c dc,h,v,p: 52% 19% 25%  3%
# [libx264 @ 0x630536c8c3c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x630536c8c3c0] ref P L0: 67.9%  2.6% 18.5% 11.0%
# [libx264 @ 0x630536c8c3c0] ref B L0: 82.5% 15.4%  2.1%
# [libx264 @ 0x630536c8c3c0] ref B L1: 95.6%  4.4%
# [libx264 @ 0x630536c8c3c0] kb/s:370.35
# [aac @ 0x630536c67540] Qavg: 3405.495
